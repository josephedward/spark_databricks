# %%
# create simple RDD 
spark.range(10).rdd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[1]: MapPartitionsRDD[5] at javaToPython at NativeMethodAccessorImpl.java:0</div>

# %%
# convert this Row-type object to the correct data type or extract values out of it
spark.range(10).toDF("id").rdd.map(lambda row: row[0])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: PythonRDD[12] at RDD at PythonRDD.scala:58</div>

# %%
# create a DataFrame or Dataset from an RDD with the toDF method on the RDD
display(spark.range(10).rdd.toDF())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th></tr></thead><tbody><tr><td>0</td></tr><tr><td>1</td></tr><tr><td>2</td></tr><tr><td>3</td></tr><tr><td>4</td></tr><tr><td>5</td></tr><tr><td>6</td></tr><tr><td>7</td></tr><tr><td>8</td></tr><tr><td>9</td></tr></tbody></table></div>

# %% [markdown]
# To create an RDD from a collection
# -  you will need to use the parallelize method on a SparkContext (within a SparkSession) - This turns a single node collection into a parallel collection.
# -  creating this parallel collection, you can also explicitly state the number of partitions into which you would like to distribute this array.

# %%
myCollection = "Spark The Definitive Guide : Big Data Processing Made Simple"\
  .split(" ")
words = spark.sparkContext.parallelize(myCollection, 2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# name this RDD to show up in the Spark UI accordingto a given name
words.setName("myWords")
words.name() # myWords
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">myWords ParallelCollectionRDD[40] at readRDDFromInputStream at PythonRDD.scala:413
# </div>

# %%
 spark.sparkContext.textFile("/FileStore/tables/sample_libsvm_data.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/FileStore/tables/sample_libsvm_data.txt MapPartitionsRDD[46] at textFile at NativeMethodAccessorImpl.java:0
# </div>

# %%
spark.sparkContext.wholeTextFiles("/FileStore/tables/sample_libsvm_data.txt")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;IPython.core.display.Javascript object&gt;
# </div>

# %%
words.distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: 10</div>

# %%
def startsWithS(individual):
  return individual.startswith("S")


print(startsWithS("Studious"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">True
# </div>

# %%
# run on each member of a collection
words.filter(lambda word: startsWithS(word)).collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[30]: [&#39;Spark&#39;, &#39;Simple&#39;]</div>

# %%
# Map the current word to the word, its starting letter, and whether the word begins with “S" - defining our functions completely inline using the relevant lambda syntax

words2 = words.map(lambda word: (word, word[0], word.startswith("S")))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#  filter on this by selecting the relevant Boolean value in a new function

words2.filter(lambda record: record[2]).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[35]: [(&#39;Spark&#39;, &#39;S&#39;, True), (&#39;Simple&#39;, &#39;S&#39;, True)]</div>

# %%
# flatMap requires that the ouput of the map function be an iterable that can be expanded

words.flatMap(lambda word: list(word)).take(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[37]: [&#39;S&#39;, &#39;p&#39;, &#39;a&#39;, &#39;r&#39;, &#39;k&#39;]</div>

# %%
# sorts by word length from longest to shortest:

words.sortBy(lambda word: len(word) * -1).take(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[40]: [&#39;Definitive&#39;,
#  &#39;Processing&#39;,
#  &#39;Simple&#39;,
#  &#39;Spark&#39;,
#  &#39;Guide&#39;,
#  &#39;Data&#39;,
#  &#39;Made&#39;,
#  &#39;The&#39;,
#  &#39;Big&#39;,
#  &#39;:&#39;]</div>

# %%
fiftyFiftySplit = words.randomSplit([0.5, 0.5])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# reduce this to its sum by specifying a function that takes as input two values and reduces them into one

spark.sparkContext.parallelize(range(1, 21)).reduce(lambda x, y: x + y)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: 210</div>

# %%
# use function to reduce to single value 
# This reducer is a good example because you can get one of two outputs. 
# Because the reduce operation on the partitions is not deterministic, you can have either “definitive” or “processing”(both of length 10) as the “left” word. 
# This means that sometimes you can end up with one, whereas other times you end up with the other


def wordLengthReducer(leftWord, rightWord):
  if len(leftWord) > len(rightWord):
    return leftWord
  else:
    return rightWord

words.reduce(wordLengthReducer)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[46]: &#39;Processing&#39;</div>

# %%
words.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[47]: 10</div>

# %% [markdown]
# countApprox
# - an approximation of the count method  - but it must execute within a timeout
# - can return incomplete results if it exceeds the timeout
# - The confidence is the probability that the error bounds of the result will contain the true value
# - if countApprox were called repeatedly with confidence 0.9, we would expect 90% of the results to contain the true count
# - The confidence must be in the range [0,1], or an exception will be thrown

# %%
confidence=0.95
timeoutMilliseconds=400
words.countApprox(timeoutMilliseconds,confidence)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: 10</div>

# %%
words.countApproxDistinct(0.05)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[50]: 10</div>

# %%
words.countApproxDistinct(4,10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">TypeError</span>                                 Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3416199129397238&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>words<span class="ansi-blue-fg">.</span>countApproxDistinct<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">4</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">10</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">TypeError</span>: countApproxDistinct() takes from 1 to 2 positional arguments but 3 were given</div>

# %%
words.countByValue()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[53]: defaultdict(int,
#             {&#39;Spark&#39;: 1,
#              &#39;The&#39;: 1,
#              &#39;Definitive&#39;: 1,
#              &#39;Guide&#39;: 1,
#              &#39;:&#39;: 1,
#              &#39;Big&#39;: 1,
#              &#39;Data&#39;: 1,
#              &#39;Processing&#39;: 1,
#              &#39;Made&#39;: 1,
#              &#39;Simple&#39;: 1})</div>

# %%
words.countByValueApprox(1000,0.95)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">AttributeError</span>                            Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-3416199129397240&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-fg">----&gt; 1</span><span class="ansi-red-fg"> </span>words<span class="ansi-blue-fg">.</span>countByValueApprox<span class="ansi-blue-fg">(</span><span class="ansi-cyan-fg">1000</span><span class="ansi-blue-fg">,</span><span class="ansi-cyan-fg">0.95</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-red-fg">AttributeError</span>: &#39;RDD&#39; object has no attribute &#39;countByValueApprox&#39;</div>

# %%
spark.sparkContext.parallelize(1 to 20).max()
spark.sparkContext.parallelize(1 to 20).min()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-cyan-fg">  File </span><span class="ansi-green-fg">&#34;&lt;command-3416199129397242&gt;&#34;</span><span class="ansi-cyan-fg">, line </span><span class="ansi-green-fg">1</span>
# <span class="ansi-red-fg">    spark.sparkContext.parallelize(1 to 20).max()</span>
#                                       ^
# <span class="ansi-red-fg">SyntaxError</span><span class="ansi-red-fg">:</span> invalid syntax
# </div>

# %%
words.take(5)
words.takeOrdered(5)
words.top(5)
withReplacement=True
numberToTake=6
randomSeed=100
words.takeSample(withReplacement,numberToTake,randomSeed)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[58]: [&#39;Data&#39;, &#39;Definitive&#39;, &#39;Data&#39;, &#39;The&#39;, &#39;Definitive&#39;, &#39;Spark&#39;]</div>

# %%
words.getStorageLevel()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[59]: StorageLevel(False, False, False, False, 1)</div>

# %% [markdown]
# mapPartitions
# - The previous command revealed that Spark operates on a per-partition basis when it comes to actually executing code
# -  You also might have noticed earlier that the return signature of a map function on an RDD is actually MapPartitionsRDD
# - This is because map is just a row-wise alias for mapPartitions, which makes it possible for you to map an individual partition - represented as an iterator
# -  That’s because physically on the cluster we operate on each partition individually - not a specific row
# - Needs a return value to work properly
#
#
#  A simple example creates the value “1” for every partition in our data, and the sum of the following expression will count the number of partitions we have:

# %%
words.mapPartitions(lambda part: [1]).sum() # 2
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[60]: 2</div>

# %% [markdown]
# foreachPartition
# -  iterates over all the partitions of the data - but the function has no return value
# - great for doing something with each partition like writing it out to a database
# - This is how many data source connectors are written
#
# Can create our own text file source if you want by specifying outputs to the temp directory with a random ID:

# %%
def indexedFunc(partitionIndex, withinPartIterator):
  return ["partition: {} => {}".format(partitionIndex,
    x) for x in withinPartIterator]
words.mapPartitionsWithIndex(indexedFunc).collect()

# %% [markdown]
# glom
# -  takes every partition in your dataset and converts them to arrays
# - can be useful if you’re going to collect the data to the driver and want to have an array for each partition
# - can cause serious stability issues because if you have large partitions or a large number of partitions
# - easy to crash the driver
#
#
# In the following example, you can see that we get two partitions and each word falls into one partition each:

# %%
spark.sparkContext.parallelize(["Hello", "World"], 2).glom().collect()
# [['Hello'], ['World']]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[61]: [[&#39;Hello&#39;], [&#39;World&#39;]]</div>
