# %% [markdown]
# Create a DataFrame:

# %%
df = spark.read.format("json").load("/FileStore/tables/2015_summary.json")
# "/FileStore/tables/2015_summary.json"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Print the Schema:

# %%
spark.read.format("json").load("/FileStore/tables/2015_summary.json").schema
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: StructType(List(StructField(DEST_COUNTRY_NAME,StringType,true),StructField(ORIGIN_COUNTRY_NAME,StringType,true),StructField(count,LongType,true)))</div>

# %% [markdown]
# Create and enforce a specific schema on a DataFrame:

# %%
from pyspark.sql.types import StructField, StructType, StringType, LongType

myManualSchema = StructType([
  StructField("DEST_COUNTRY_NAME", StringType(), True),
  StructField("ORIGIN_COUNTRY_NAME", StringType(), True),
  StructField("count", LongType(), False, metadata={"hello":"world"})
])
df = spark.read.format("json").schema(myManualSchema)\
  .load("/FileStore/tables/2015_summary.json")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Construct a column. Columns are not resolved until we compare the column names with those we are maintaining in the catalog. Column and table resolution happens in the analyzer phase.

# %%
from pyspark.sql.functions import col, column
col("someColumnName")
column("someColumnName")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[4]: Column&lt;b&#39;someColumnName&#39;&gt;</div>

# %% [markdown]
# **Columns as Expressions**
# *expr("someCol - 5")* is the same transformation as performing *col("someCol") - 5*, or even *expr("someCol") - 5*. That’s because Spark compiles these to a logical tree specifying the order of operations

# %%
from pyspark.sql.functions import expr
expr("(((someCol + 5) * 200) - 6) < otherCol")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[5]: Column&lt;b&#39;((((someCol + 5) * 200) - 6) &lt; otherCol)&#39;&gt;</div>

# %% [markdown]
# The above is a directed acyclic graph. This graph is represented equivalently by this code:

# %%
(((col("someCol")+5)*200)-6)<col("otherCol")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[6]: Column&lt;b&#39;((((someCol + 5) * 200) - 6) &lt; otherCol)&#39;&gt;</div>

# %% [markdown]
# The previous expression is actually valid SQL code, as well, just like you might put in a SELECT statement. This SQL expression and the previous DataFrame code compile to the same underlying logical tree prior to execution. You can write your expressions as DataFrame code or as SQL expressions and get the exact same performance characteristics.

# %% [markdown]
# if you want to programmatically access columns, you can use the columns property to see all columns on a DataFrame:

# %%
spark.read.format("json").load("/FileStore/tables/2015_summary.json").columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: [&#39;DEST_COUNTRY_NAME&#39;, &#39;ORIGIN_COUNTRY_NAME&#39;, &#39;count&#39;]</div>

# %% [markdown]
# Can create rows by manually instantiating a Row object with the values that belong in each column.

# %%
from pyspark.sql import Row
myRow = Row("Hello", None, 1, False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Access data in rows by specifing the position:

# %%
print(myRow[0])
print(myRow[2])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Hello
# 1
# </div>

# %% [markdown]
# Creates a new temporary view using a SparkDataFrame in the Spark Session. If a temporary view with the same name already exists, replaces it.

# %%
df = spark.read.format("json").load("/FileStore/tables/2015_summary.json")
df.createOrReplaceTempView("dfTable")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Create DataFrames on the fly by taking a set of rows and converting them to a DataFrame

# %%
from pyspark.sql import Row
from pyspark.sql.types import StructField, StructType, StringType, LongType
myManualSchema = StructType([
  StructField("some", StringType(), True),
  StructField("col", StringType(), True),
  StructField("names", LongType(), False)
])
myRow = Row("Hello", None, 1)
myDf = spark.createDataFrame([myRow], myManualSchema)
myDf.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+----+-----+
#  some| col|names|
# +-----+----+-----+
# Hello|null|    1|
# +-----+----+-----+
#
# </div>

# %% [markdown]
# Use the select method and pass in thecolumn names as strings with which you would like to work

# %%
df.select("DEST_COUNTRY_NAME").show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
# DEST_COUNTRY_NAME|
# +-----------------+
#     United States|
#     United States|
# +-----------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# Select multiple columns by using the same style of query:

# %%
df.select("DEST_COUNTRY_NAME", "ORIGIN_COUNTRY_NAME").show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|
# +-----------------+-------------------+
#     United States|            Romania|
#     United States|            Croatia|
# +-----------------+-------------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# Refer to columns in a number of different ways -  use them interchangeably:

# %%
from pyspark.sql.functions import expr, col, column
df.select(
    expr("DEST_COUNTRY_NAME"),
    col("DEST_COUNTRY_NAME"),
    column("DEST_COUNTRY_NAME"))\
  .show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-----------------+-----------------+
# DEST_COUNTRY_NAME|DEST_COUNTRY_NAME|DEST_COUNTRY_NAME|
# +-----------------+-----------------+-----------------+
#     United States|    United States|    United States|
#     United States|    United States|    United States|
# +-----------------+-----------------+-----------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# *expr* is the most flexible reference - can refer to a plain column or a string manipulation of a column - Change the column name, and then change it back by using the AS keyword and then the alias method on the column:

# %%
df.select(expr("DEST_COUNTRY_NAME AS destination")).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+
#   destination|
# +-------------+
# United States|
# United States|
# +-------------+
# only showing top 2 rows
#
# </div>

# %%
df.select(expr("DEST_COUNTRY_NAME as destination").alias("DEST_COUNTRY_NAME"))\
  .show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
# DEST_COUNTRY_NAME|
# +-----------------+
#     United States|
#     United States|
# +-----------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# **selectExpr** shorthand:

# %%
df.selectExpr("DEST_COUNTRY_NAME as newColumnName", "DEST_COUNTRY_NAME").show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------+-----------------+
# newColumnName|DEST_COUNTRY_NAME|
# +-------------+-----------------+
# United States|    United States|
# United States|    United States|
# +-------------+-----------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# Adds a new column within Country to our DataFrame that specifies whether the destination and origin are the same:

# %%
df.selectExpr(
  "*", # all original columns
  "(DEST_COUNTRY_NAME = ORIGIN_COUNTRY_NAME) as withinCountry")\
  .show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+-------------+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|withinCountry|
# +-----------------+-------------------+-----+-------------+
#     United States|            Romania|   15|        false|
#     United States|            Croatia|    1|        false|
# +-----------------+-------------------+-----+-------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# Specify aggregations over the entire DataFrame:

# %%
df.selectExpr("avg(count)", "count(distinct(DEST_COUNTRY_NAME))").show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+---------------------------------+
#  avg(count)|count(DISTINCT DEST_COUNTRY_NAME)|
# +-----------+---------------------------------+
# 1770.765625|                              132|
# +-----------+---------------------------------+
#
# </div>

# %% [markdown]
# Literals - pass explicit values into Spark that are just a value (rather than a new column) - a constant value, or something needed for later comparisons

# %%
from pyspark.sql.functions import lit
df.select(expr("*"), lit(1).alias("One")).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+---+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|One|
# +-----------------+-------------------+-----+---+
#     United States|            Romania|   15|  1|
#     United States|            Croatia|    1|  1|
# +-----------------+-------------------+-----+---+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# Another way to add a column:

# %%
df.withColumn("numberOne", lit(1)).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+---------+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|numberOne|
# +-----------------+-------------------+-----+---------+
#     United States|            Romania|   15|        1|
#     United States|            Croatia|    1|        1|
# +-----------------+-------------------+-----+---------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# Set a Boolean flag for when the origin country is the same as the destination country:

# %%
df.withColumn("withinCountry", expr("ORIGIN_COUNTRY_NAME == DEST_COUNTRY_NAME"))\
  .show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+-------------+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|withinCountry|
# +-----------------+-------------------+-----+-------------+
#     United States|            Romania|   15|        false|
#     United States|            Croatia|    1|        false|
# +-----------------+-------------------+-----+-------------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# withColumnRenamed - rename the column with the name of the string in the first argument to the string in the second argument

# %%
df.withColumnRenamed("DEST_COUNTRY_NAME", "dest").columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [&#39;dest&#39;, &#39;ORIGIN_COUNTRY_NAME&#39;, &#39;count&#39;]</div>

# %%
dfWithLongColName = df.withColumn(
    "This Long Column-Name",
    expr("ORIGIN_COUNTRY_NAME"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Using escape characters:

# %%
dfWithLongColName.selectExpr(
    "`This Long Column-Name`",
    "`This Long Column-Name` as `new col`")\
  .show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------------+-------+
# This Long Column-Name|new col|
# +---------------------+-------+
#               Romania|Romania|
#               Croatia|Croatia|
# +---------------------+-------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# Can refer to columns with reserved characters (and not escape them) if we’re doing an explicit string-to-column reference, which is interpreted as a literal instead of an expression:

# %%
dfWithLongColName.select(expr("`This Long Column-Name`")).columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[19]: [&#39;This Long Column-Name&#39;]</div>

# %% [markdown]
# Filter rows, we create an expression that evaluates to true or false:

# %%
df.where(col("count") < 2).where(col("ORIGIN_COUNTRY_NAME") != "Croatia")\
  .show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
#     United States|          Singapore|    1|
#           Moldova|      United States|    1|
# +-----------------+-------------------+-----+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# If you want to specify multiple AND filters, just chain them sequentially:

# %%
df.select("ORIGIN_COUNTRY_NAME", "DEST_COUNTRY_NAME").distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: 256</div>

# %% [markdown]
# Very common use case is to extract the unique or distinct values:

# %%
df.select("ORIGIN_COUNTRY_NAME").distinct().count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: 125</div>

# %% [markdown]
# Random Sampling:

# %%
seed = 5
withReplacement = False
fraction = 0.5
df.sample(withReplacement, fraction, seed).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[23]: 138</div>

# %% [markdown]
# Random splits - setting the weights by which we will split the DataFrame, seed,

# %%
dataFrames = df.randomSplit([0.25, 0.75], seed)
dataFrames[0].count() > dataFrames[1].count() # False
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: False</div>

# %% [markdown]
# To append to a DataFrame, you must union the original DataFrame along with the new DataFrame, and you must be sure that they have the same schema and number of columns; otherwise, the union will fail(!)

# %%
from pyspark.sql import Row
schema = df.schema
newRows = [
  Row("New Country", "Other Country", 5L),
  Row("New Country 2", "Other Country 3", 1L)
]
parallelizedRows = spark.sparkContext.parallelize(newRows)
newDF = spark.createDataFrame(parallelizedRows, schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-cyan-fg">  File </span><span class="ansi-green-fg">&#34;&lt;command-3225676469214782&gt;&#34;</span><span class="ansi-cyan-fg">, line </span><span class="ansi-green-fg">4</span>
# <span class="ansi-red-fg">    Row(&#34;New Country&#34;, &#34;Other Country&#34;, 5L),</span>
#                                          ^
# <span class="ansi-red-fg">SyntaxError</span><span class="ansi-red-fg">:</span> invalid syntax
# </div>

# %% [markdown]
# Python 3.X integers support unlimited size in contrast to Python 2.X that has a separate type for long integers (remove the L)

# %%
from pyspark.sql import Row
schema = df.schema
newRows = [
  Row("New Country", "Other Country", 5),
  Row("New Country 2", "Other Country 3", 1)
]
parallelizedRows = spark.sparkContext.parallelize(newRows)
newDF = spark.createDataFrame(parallelizedRows, schema)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.union(newDF)\
  .where("count = 1")\
  .where(col("ORIGIN_COUNTRY_NAME") != "United States")\
  .show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
#     United States|            Croatia|    1|
#     United States|          Singapore|    1|
#     United States|          Gibraltar|    1|
#     United States|             Cyprus|    1|
#     United States|            Estonia|    1|
#     United States|          Lithuania|    1|
#     United States|           Bulgaria|    1|
#     United States|            Georgia|    1|
#     United States|            Bahrain|    1|
#     United States|   Papua New Guinea|    1|
#     United States|         Montenegro|    1|
#     United States|            Namibia|    1|
#     New Country 2|    Other Country 3|    1|
# +-----------------+-------------------+-----+
#
# </div>

# %% [markdown]
# Sort with either the largest or smallest values at the top of a DataFrame. Two equivalent operations to do this - sort and orderBy - that work the exact same way. They accept both column expressions and strings as well as multiple columns. The default is to sort in ascending order.

# %%
df.sort("count").show(5)
df.orderBy("count", "DEST_COUNTRY_NAME").show(5)
df.orderBy(col("count"), col("DEST_COUNTRY_NAME")).show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------------+-----+
#    DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +--------------------+-------------------+-----+
#                Malta|      United States|    1|
# Saint Vincent and...|      United States|    1|
#        United States|            Croatia|    1|
#        United States|          Gibraltar|    1|
#        United States|          Singapore|    1|
# +--------------------+-------------------+-----+
# only showing top 5 rows
#
# +-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
#      Burkina Faso|      United States|    1|
#     Cote d&#39;Ivoire|      United States|    1|
#            Cyprus|      United States|    1|
#          Djibouti|      United States|    1|
#         Indonesia|      United States|    1|
# +-----------------+-------------------+-----+
# only showing top 5 rows
#
# +-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
#      Burkina Faso|      United States|    1|
#     Cote d&#39;Ivoire|      United States|    1|
#            Cyprus|      United States|    1|
#          Djibouti|      United States|    1|
#         Indonesia|      United States|    1|
# +-----------------+-------------------+-----+
# only showing top 5 rows
#
# </div>

# %% [markdown]
# To more explicitly specify sort direction, you need to use the asc and desc functions if operating on a column:

# %%
from pyspark.sql.functions import desc, asc
df.orderBy(expr("count desc")).show(2)
df.orderBy(col("count").desc(), col("DEST_COUNTRY_NAME").asc()).show(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
#           Moldova|      United States|    1|
#     United States|            Croatia|    1|
# +-----------------+-------------------+-----+
# only showing top 2 rows
#
# +-----------------+-------------------+------+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME| count|
# +-----------------+-------------------+------+
#     United States|      United States|370002|
#     United States|             Canada|  8483|
# +-----------------+-------------------+------+
# only showing top 2 rows
#
# </div>

# %% [markdown]
# Sort within Partitions to Optimize Porpoises:

# %%
spark.read.format("json").load("/FileStore/tables/2015_summary.json")\
  .sortWithinPartitions("count")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[38]: DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: bigint]</div>

# %%
df.limit(5).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
#     United States|            Romania|   15|
#     United States|            Croatia|    1|
#     United States|            Ireland|  344|
#             Egypt|      United States|   15|
#     United States|              India|   62|
# +-----------------+-------------------+-----+
#
# </div>

# %%
df.orderBy(expr("count desc")).limit(6).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-------------------+-----+
#    DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +--------------------+-------------------+-----+
#                Malta|      United States|    1|
# Saint Vincent and...|      United States|    1|
#        United States|            Croatia|    1|
#        United States|          Gibraltar|    1|
#        United States|          Singapore|    1|
#              Moldova|      United States|    1|
# +--------------------+-------------------+-----+
#
# </div>

# %% [markdown]
# Only repartition when the future number of partitions is greaterthan your current number of partitions or when you are looking to partition by a set of columns:

# %%
df.rdd.getNumPartitions() # 1
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[41]: 1</div>

# %%
df.repartition(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[42]: DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: bigint]</div>

# %% [markdown]
# Filtering by a certain column often - can be worth repartitioning based on that column:

# %%
df.repartition(col("DEST_COUNTRY_NAME"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[43]: DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: bigint]</div>

# %%
df.repartition(5, col("DEST_COUNTRY_NAME"))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[44]: DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: bigint]</div>

# %% [markdown]
# Coalesce will not incur a full shuffle,  and will try to combine partitions. This operation will shuffle your data into five partitions based on the destination country name, and then coalesce them (without a full shuffle).

# %%
df.repartition(5, col("DEST_COUNTRY_NAME")).coalesce(2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[45]: DataFrame[DEST_COUNTRY_NAME: string, ORIGIN_COUNTRY_NAME: string, count: bigint]</div>

# %% [markdown]
# Spark maintains the state of the cluster in the driver. There are times when you’ll want to collect some of your data to the driver in order to manipulate it on your local machine. *Collect* gets all data from the entire DataFrame, *take* selects the first N rows, and *show* prints out a number of rows.

# %%
collectDF = df.limit(10)
collectDF.take(5) # take works with an Integer count
collectDF.show() # this prints it out nicely
collectDF.show(5, False)
collectDF.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
#     United States|            Romania|   15|
#     United States|            Croatia|    1|
#     United States|            Ireland|  344|
#             Egypt|      United States|   15|
#     United States|              India|   62|
#     United States|          Singapore|    1|
#     United States|            Grenada|   62|
#        Costa Rica|      United States|  588|
#           Senegal|      United States|   40|
#           Moldova|      United States|    1|
# +-----------------+-------------------+-----+
#
# +-----------------+-------------------+-----+
# DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +-----------------+-------------------+-----+
# United States    |Romania            |15   |
# United States    |Croatia            |1    |
# United States    |Ireland            |344  |
# Egypt            |United States      |15   |
# United States    |India              |62   |
# +-----------------+-------------------+-----+
# only showing top 5 rows
#
# Out[46]: [Row(DEST_COUNTRY_NAME=&#39;United States&#39;, ORIGIN_COUNTRY_NAME=&#39;Romania&#39;, count=15),
#  Row(DEST_COUNTRY_NAME=&#39;United States&#39;, ORIGIN_COUNTRY_NAME=&#39;Croatia&#39;, count=1),
#  Row(DEST_COUNTRY_NAME=&#39;United States&#39;, ORIGIN_COUNTRY_NAME=&#39;Ireland&#39;, count=344),
#  Row(DEST_COUNTRY_NAME=&#39;Egypt&#39;, ORIGIN_COUNTRY_NAME=&#39;United States&#39;, count=15),
#  Row(DEST_COUNTRY_NAME=&#39;United States&#39;, ORIGIN_COUNTRY_NAME=&#39;India&#39;, count=62),
#  Row(DEST_COUNTRY_NAME=&#39;United States&#39;, ORIGIN_COUNTRY_NAME=&#39;Singapore&#39;, count=1),
#  Row(DEST_COUNTRY_NAME=&#39;United States&#39;, ORIGIN_COUNTRY_NAME=&#39;Grenada&#39;, count=62),
#  Row(DEST_COUNTRY_NAME=&#39;Costa Rica&#39;, ORIGIN_COUNTRY_NAME=&#39;United States&#39;, count=588),
#  Row(DEST_COUNTRY_NAME=&#39;Senegal&#39;, ORIGIN_COUNTRY_NAME=&#39;United States&#39;, count=40),
#  Row(DEST_COUNTRY_NAME=&#39;Moldova&#39;, ORIGIN_COUNTRY_NAME=&#39;United States&#39;, count=1)]</div>

# %% [markdown]
# The method toLocalIterator collects partitions to the driver as an iterator - allows you to iterate over the entire dataset partition-by-partition in a serial manner.

# %%
collectDF.toLocalIterator()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[48]: &lt;generator object _local_iterator_from_socket.&lt;locals&gt;.PyLocalIterable.__iter__ at 0x7f7208c0a450&gt;</div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
